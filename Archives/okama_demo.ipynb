# %%
# !pip install okama
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: okama in c:\users\sakshi aherkar\appdata\roaming\python\python312\site-packages (1.4.1)
# Requirement already satisfied: joblib in c:\programdata\anaconda3\lib\site-packages (from okama) (1.4.2)
# Requirement already satisfied: matplotlib>=3.5.1 in c:\programdata\anaconda3\lib\site-packages (from okama) (3.8.4)
# Requirement already satisfied: pandas<3.0.0,>=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from okama) (2.2.2)
# Requirement already satisfied: requests in c:\programdata\anaconda3\lib\site-packages (from okama) (2.32.2)
# Requirement already satisfied: scipy>=1.9.0 in c:\programdata\anaconda3\lib\site-packages (from okama) (1.13.1)
# Requirement already satisfied: setuptools in c:\programdata\anaconda3\lib\site-packages (from okama) (69.5.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib>=3.5.1->okama) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\programdata\anaconda3\lib\site-packages (from matplotlib>=3.5.1->okama) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\programdata\anaconda3\lib\site-packages (from matplotlib>=3.5.1->okama) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib>=3.5.1->okama) (1.4.4)
# Requirement already satisfied: numpy>=1.21 in c:\programdata\anaconda3\lib\site-packages (from matplotlib>=3.5.1->okama) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\programdata\anaconda3\lib\site-packages (from matplotlib>=3.5.1->okama) (23.2)
# Requirement already satisfied: pillow>=8 in c:\programdata\anaconda3\lib\site-packages (from matplotlib>=3.5.1->okama) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib>=3.5.1->okama) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\programdata\anaconda3\lib\site-packages (from matplotlib>=3.5.1->okama) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\programdata\anaconda3\lib\site-packages (from pandas<3.0.0,>=2.0.0->okama) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\programdata\anaconda3\lib\site-packages (from pandas<3.0.0,>=2.0.0->okama) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\programdata\anaconda3\lib\site-packages (from requests->okama) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests->okama) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests->okama) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests->okama) (2024.7.4)
# Requirement already satisfied: six>=1.5 in c:\programdata\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.5.1->okama) (1.16.0)

# %%
import okama as ok
import pandas as pd

x = ok.AssetList(['SPY.US', 'BND.US', 'DBXD.XFRA'], ccy='USD')
x  #
# Out:
# assets           [SPY.US, BND.US, DBXD.XFRA]
# currency                                 USD
# first_date                           2007-05
# last_date                            2024-08
# period_length             17 years, 4 months
# inflation                           USD.INFL
# dtype: object

# %%
x.describe()
# Out:
# C:\Users\Sakshi Aherkar\AppData\Roaming\Python\Python312\site-packages\okama\asset.py:175: FutureWarning: Resampling with a PeriodIndex is deprecated. Cast index to DatetimeIndex before resampling instead.
#   return div.resample("M").sum()
# C:\Users\Sakshi Aherkar\AppData\Roaming\Python\Python312\site-packages\okama\asset.py:175: FutureWarning: Resampling with a PeriodIndex is deprecated. Cast index to DatetimeIndex before resampling instead.
#   return div.resample("M").sum()
# C:\Users\Sakshi Aherkar\AppData\Roaming\Python\Python312\site-packages\okama\asset.py:175: FutureWarning: Resampling with a PeriodIndex is deprecated. Cast index to DatetimeIndex before resampling instead.
#   return div.resample("M").sum()
#                   property              period    SPY.US    BND.US DBXD.XFRA  \
# 0          Compound return                 YTD  0.193525  0.032332  0.125936
# 1                     CAGR             1 years  0.269303  0.073232  0.196426
# 2                     CAGR             5 years  0.158443 -0.001007   0.09191
# 3                     CAGR            10 years  0.128772  0.015913  0.048648
# 4                     CAGR  17 years, 4 months  0.100921  0.030164  0.039005
# 5   Annualized mean return  17 years, 4 months  0.114745  0.031246  0.067197
# 6           Dividend yield                 LTM   0.01214   0.03376       0.0
# 7                     Risk  17 years, 4 months  0.175659  0.047392  0.247907
# 8                     CVAR  17 years, 4 months  0.408323   0.15194  0.505738
# 9            Max drawdowns  17 years, 4 months -0.507799 -0.175337 -0.587564
# 10     Max drawdowns dates  17 years, 4 months   2009-02   2022-10   2009-02
# 11          Inception date                None   1993-02   2007-05   2007-02
# 12         Last asset date                None   2024-09   2024-09   2024-09
# 13   Common last data date                None   2024-08   2024-08   2024-08
#
#    inflation
# 0   0.026274
# 1   0.025345
# 2   0.041809
# 3   0.028447
# 4   0.024578
# 5        NaN
# 6        NaN
# 7        NaN
# 8        NaN
# 9        NaN
# 10       NaN
# 11   2007-05
# 12   2024-08
# 13   2024-08

# %%
x.wealth_indexes.plot()
# Out:
# <Axes: xlabel='date'>

# %%
weights = [0.3, 0.2, 0.2, 0.2, 0.1]
assets = ['T.US', 'XOM.US', 'FRE.XFRA', 'SNW.XFRA', 'LKOH.MOEX']
pf = ok.Portfolio(assets, weights=weights, ccy='EUR')
pf.table
# Out:
#                 asset name     ticker  weights
# 0                 AT&T Inc       T.US      0.3
# 1         Exxon Mobil Corp     XOM.US      0.2
# 2  Fresenius SE & Co. KGaA   FRE.XFRA      0.2
# 3                   Sanofi   SNW.XFRA      0.2
# 4            NK Lukoil PAO  LKOH.MOEX      0.1
