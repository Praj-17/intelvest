# %% [markdown]
# <a href="https://colab.research.google.com/github/mbk-dev/okama/blob/master/examples/03%20investment%20portfolios.ipynb"><img align="left" src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open in Colab" title="Open and Execute in Google Colaboratory"></a>

# %% [markdown]
# You can run the code examples in [Google Colab](https://colab.research.google.com/github/mbk-dev/okama/blob/master/examples/03%20investment%20portfolios.ipynb).

# %% [markdown]
# **To install the package:**

# %%
# !pip install okama
# Out:
# [notice] A new release of pip is available: 24.1.2 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: okama in c:\users\sakshi aherkar\appdata\roaming\python\python312\site-packages (1.4.1)
# Requirement already satisfied: joblib in c:\users\sakshi aherkar\.conda\envs\chat\lib\site-packages (from okama) (1.4.2)
# Requirement already satisfied: matplotlib>=3.5.1 in c:\users\sakshi aherkar\.conda\envs\chat\lib\site-packages (from okama) (3.9.1.post1)
# Requirement already satisfied: pandas<3.0.0,>=2.0.0 in c:\users\sakshi aherkar\.conda\envs\chat\lib\site-packages (from okama) (2.2.2)
# Requirement already satisfied: requests in c:\users\sakshi aherkar\.conda\envs\chat\lib\site-packages (from okama) (2.32.3)
# Requirement already satisfied: scipy>=1.9.0 in c:\users\sakshi aherkar\.conda\envs\chat\lib\site-packages (from okama) (1.14.0)
# Requirement already satisfied: setuptools in c:\users\sakshi aherkar\.conda\envs\chat\lib\site-packages (from okama) (69.5.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\sakshi aherkar\.conda\envs\chat\lib\site-packages (from matplotlib>=3.5.1->okama) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\sakshi aherkar\.conda\envs\chat\lib\site-packages (from matplotlib>=3.5.1->okama) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\sakshi aherkar\.conda\envs\chat\lib\site-packages (from matplotlib>=3.5.1->okama) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\sakshi aherkar\.conda\envs\chat\lib\site-packages (from matplotlib>=3.5.1->okama) (1.4.5)
# Requirement already satisfied: numpy>=1.23 in c:\users\sakshi aherkar\.conda\envs\chat\lib\site-packages (from matplotlib>=3.5.1->okama) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\sakshi aherkar\.conda\envs\chat\lib\site-packages (from matplotlib>=3.5.1->okama) (23.2)
# Requirement already satisfied: pillow>=8 in c:\users\sakshi aherkar\.conda\envs\chat\lib\site-packages (from matplotlib>=3.5.1->okama) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\sakshi aherkar\.conda\envs\chat\lib\site-packages (from matplotlib>=3.5.1->okama) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\sakshi aherkar\.conda\envs\chat\lib\site-packages (from matplotlib>=3.5.1->okama) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\sakshi aherkar\.conda\envs\chat\lib\site-packages (from pandas<3.0.0,>=2.0.0->okama) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\sakshi aherkar\.conda\envs\chat\lib\site-packages (from pandas<3.0.0,>=2.0.0->okama) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\sakshi aherkar\.conda\envs\chat\lib\site-packages (from requests->okama) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sakshi aherkar\.conda\envs\chat\lib\site-packages (from requests->okama) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\sakshi aherkar\.conda\envs\chat\lib\site-packages (from requests->okama) (1.26.19)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sakshi aherkar\.conda\envs\chat\lib\site-packages (from requests->okama) (2024.7.4)
# Requirement already satisfied: six>=1.5 in c:\users\sakshi aherkar\.conda\envs\chat\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.5.1->okama) (1.16.0)

# %% [markdown]
# import okama and matplotlib packages ...

# %%
import warnings

import matplotlib.pyplot as plt

plt.rcParams["figure.figsize"] = [12.0, 6.0]
warnings.simplefilter(action="ignore", category=FutureWarning)

import okama as ok

# %% [markdown]
# **Portfolio** and **AssetList** can be helpful to learn about investment portfolio properties and to compare various portfolios with each other. With **AssetList** we can even compare portfolio with stocks, indexes and other types of financial assets (portfolio is just a special case of a financial asset).

# %% [markdown]
# In this tutorial we will learn how to:
#
# - Create investment portfolio and see its basic properties
# - Rebalancing strategy and asset allocation
# - Risk metrics of the portfolio
# - Accumulated return, CAGR and dividend yield
# - Compare several portfolios
# - Forecast portfolios performance

# %% [markdown]
# ### Create an investment portfolio

# %% [markdown]
# Portfolios are quite similar to AssetList, but we should specify **weights** and **rebalancing** strategy.

# %% [markdown]
# All the arguments have default values and can be skipped.

# %%
basic_portfolio = ok.Portfolio()
basic_portfolio
# Out:
# symbol                 portfolio_8328.PF
# assets                          [SPY.US]
# weights                            [1.0]
# rebalancing_period                 month
# currency                             USD
# inflation                       USD.INFL
# first_date                       1993-02
# last_date                        2024-09
# period_length         31 years, 8 months
# dtype: object

# %% [markdown]
# Default ticker is 'SPY.US'.
# Default currency is 'USD'.
# Default rebalancing period is one month.
# Inflation is included by default: `inflation=True`
# If portfolio has several assets they are included with equal weights by default.

# %% [markdown]
# Let’s create Rick Ferri's Lazy Three Fund Portfolio (40/40/20).
# Rebalancing period should be one year.
# ```
# Rebalancing is the process by which an investor restores their portfolio to its target allocation by selling and buying assets. After rebalancing all the assets have original weights.
# ```

# %% [markdown]
# **rebalancing_period** attribute can be: 'month', 'year', 'half-year', 'quarter' or 'none' (for not rebalanced portfolios).

# %%
rf3 = ok.Portfolio(
    assets=["VOO.US", "SPY.US", "QQQ.US"],
    weights=[0.40, 0.40, 0.20],
    rebalancing_period='none',
    first_date="2015-10-09",
    initial_amount= 2000.0,
    ccy="USD",
    inflation=True
)
rf3
# Out:
# symbol                       portfolio_3431.PF
# assets                [VOO.US, SPY.US, QQQ.US]
# weights                        [0.4, 0.4, 0.2]
# rebalancing_period                        none
# currency                                   USD
# inflation                             USD.INFL
# first_date                             2015-11
# last_date                              2024-09
# period_length               8 years, 11 months
# dtype: object

# %% [markdown]
# Available history date range is defined by the assets.
# Each asset has it **first_date** and **last_date** which can be shown by `.assets_first_dates` and `.assets_last_dates`

# %%
import numpy as np
import pandas as pd
from okama.settings import PeriodLength
from okama.portfolio import PortfolioDCF
from matplotlib.axes import Axes

# Define the allowed types as a tuple
allowed_types = ( list, int, str, float, np.float64, pd.Series, pd.DataFrame, pd.Timestamp, PeriodLength, PortfolioDCF, Axes)
allowed_methods = ("percentile_history_cagr", "assets_first_dates", "assets_last_dates", 
                   "currencies", "jarque_bera", "kstest", "names", "percentile_distribution_cagr","percentile_wealth")
# Iterate over all attributes of rf3
for attr in dir(rf3):
    # Skip private or special attributes
    if not attr.startswith("_"):
        # Safely get the attribute value using getattr
        attr_value = getattr(rf3, attr, None)
        
        # Check if the attribute is not one of the allowed types
        if not isinstance(attr_value, allowed_types):
            print(f"___________________{attr}___________________")
            print(f"Type: {type(attr_value)}")

            if callable(attr_value):
                try:
                    if not isinstance(attr_value(), allowed_types):
                        print(type(attr_value()))

                except:
                    print("Exception with ", attr_value)
            # print(f"Value: {attr_value}\n")  # Optional: Print the value for more context
# Out:
# ___________________asset_obj_dict___________________
# Type: <class 'dict'>
# ___________________assets_first_dates___________________
# Type: <class 'dict'>
# ___________________assets_last_dates___________________
# Type: <class 'dict'>
# ___________________assets_weights___________________
# Type: <class 'dict'>
# ___________________currencies___________________
# Type: <class 'dict'>
# ___________________describe___________________
# Type: <class 'method'>
# ___________________get_cagr___________________
# Type: <class 'method'>
# ___________________get_cumulative_return___________________
# Type: <class 'method'>
# ___________________get_cvar_historic___________________
# Type: <class 'method'>
# ___________________get_rolling_cagr___________________
# Type: <class 'method'>
# ___________________get_rolling_cumulative_return___________________
# Type: <class 'method'>
# ___________________get_sharpe_ratio___________________
# Type: <class 'method'>
# ___________________get_sortino_ratio___________________
# Type: <class 'method'>
# ___________________get_var_historic___________________
# Type: <class 'method'>
# ___________________jarque_bera___________________
# Type: <class 'dict'>
# ___________________kstest___________________
# Type: <class 'method'>
# <class 'dict'>
# ___________________kurtosis_rolling___________________
# Type: <class 'method'>
# ___________________monte_carlo_returns_ts___________________
# Type: <class 'method'>
# ___________________monte_carlo_wealth___________________
# Type: <class 'method'>
# ___________________names___________________
# Type: <class 'dict'>
# ___________________percentile_distribution_cagr___________________
# Type: <class 'method'>
# <class 'dict'>
# ___________________percentile_history_cagr___________________
# Type: <class 'method'>
# Exception with  <bound method Portfolio.percentile_history_cagr of symbol                       portfolio_3431.PF
# assets                [VOO.US, SPY.US, QQQ.US]
# weights                        [0.4, 0.4, 0.2]
# rebalancing_period                        none
# currency                                   USD
# inflation                             USD.INFL
# first_date                             2015-11
# last_date                              2024-09
# period_length               8 years, 11 months
# dtype: object>
# ___________________percentile_inverse_cagr___________________
# Type: <class 'method'>
# ___________________percentile_wealth___________________
# Type: <class 'method'>
# <class 'dict'>
# ___________________percentile_wealth_history___________________
# Type: <class 'method'>
# ___________________plot_assets___________________
# Type: <class 'method'>
# ___________________plot_forecast___________________
# Type: <class 'method'>
# ___________________plot_forecast_monte_carlo___________________
# Type: <class 'method'>
# <class 'NoneType'>
# ___________________plot_hist_fit___________________
# Type: <class 'method'>
# <class 'NoneType'>
# ___________________plot_percentiles_fit___________________
# Type: <class 'method'>
# <class 'NoneType'>
# ___________________skewness_rolling___________________
# Type: <class 'method'>

# %%
(rf3.plot_forecast_monte_carlo())

# %%
isinstance(rf3.pl, PeriodLength)
# Out:
# True

# %%
def convert_pl_to_dict(pl):
    return {
        "years": rf3.pl.years,
        "months": rf3.pl.months
    }

# %%
rf3.pl.years
rf3.pl.months
# Out:
# 11

# %%
rf3.percentile_inverse_cagr()
# Out:
# 16.6

# %% [markdown]
# Here VXUS.US is a **stock with the shortest history** which is limiting the whole portfolio data.

# %%
rf3.assets_last_dates
# Out:
# {'VOO.US': Timestamp('2024-10-01 00:00:00'),
#  'SPY.US': Timestamp('2024-10-01 00:00:00'),
#  'QQQ.US': Timestamp('2024-10-01 00:00:00'),
#  'USD': Timestamp('2099-12-01 00:00:00'),
#  'USD.INFL': Timestamp('2024-09-01 00:00:00')}

# %% [markdown]
# On the other hand, the **inflation** is limiting the data from the left side. If you need last month’s data to be included `inflation=False` should be used in Portfolio instantiating.

# %% [markdown]
# The ticker of portfolio is set automaticaly: **portfolio_8291.PF** (index is a random number).
# If you need a custom portfolio ticker you can use `symbol=` in portfolio instantiating or set it afterwards:

# %%
rf3.symbol = "RF3_portfolio.PF"  # 'PF' namespace is reserved for portfolios.

# %% [markdown]
# Wealth index (Cumulative Wealth Index) is a time series that presents the value of portfolio over historical time period. The initial investment is 1000 points in a base currency.

# %% [markdown]
# ### Rebalancing strategy and asset allocaction

# %% [markdown]
# Table with original asset allocation can be seen with `.table`:

# %%
rf3.table
# Out:
#                asset name  ticker  weights
# 0    Vanguard S&P 500 ETF  VOO.US      0.4
# 1  SPDR S&P 500 ETF Trust  SPY.US      0.4
# 2       Invesco QQQ Trust  QQQ.US      0.2

# %% [markdown]
# RF3_portfolio has one year rebalancing period hence weight are subjects to change.
# It is possible to see assets eights time series with `.weights_ts`:

# %%
rf3.weights_ts.plot();

# %% [markdown]
# let's create the same Rick Ferry portfolio, but without rebalancing (asset allocation will change and never return to the original weights).

# %%
rf3_no_rebalancing = ok.Portfolio(
    ["BND.US", "VTI.US", "VXUS.US"],
    weights=[0.40, 0.40, 0.20],
    rebalancing_period="none",
)

# %% [markdown]
# Now it's easy to see how the weights get out of control over time... and we end up with portfolio overweight in stocks.

# %%
rf3_no_rebalancing.weights_ts.plot();

# %% [markdown]
# ### Risk metrics of the portfolio

# %% [markdown]
# Portfolio has several methods to see risk metrics. By default with 'risk' we understand return time series standard deviation:
#
# - risk_monthly (standard deviation for monthly rate of return time series)
# - risk_annual (annualized standart deviation)
# - semideviation_monthly (downside risk for monthly rate of return time series)
# - semideviation_annual (annualized semideviation)
# - get_var_historic (historic Value at Risk for the portfolio)
# - get_cvar_historic (historic Conditional Value at Risk for the portfolio)
# - drawdowns (percent decline from a previous peak)
# - recovery_period (the longest recovery period after drawdown for the portfolio assets value)

# %%
rf3.risk_annual  # aanualized value for standard deviation of return
# Out:
# date
# 2015-12    0.049101
# 2016-01    0.079441
# 2016-02    0.072693
# 2016-03    0.153209
# 2016-04    0.136242
#              ...
# 2024-05    0.187525
# 2024-06    0.187595
# 2024-07    0.186544
# 2024-08    0.185811
# 2024-09    0.185148
# Freq: M, Name: RF3_portfolio.PF, Length: 106, dtype: float64

# %%
rf3.semideviation_annual  # annualized value for downside risk
# Out:
# 0.1319363075856431

# %%
rf3.get_cvar_historic(time_frame=12, level=1)  # one year CVAR with confidence level 1%
# Out:
# 0.21978020875999815

# %% [markdown]
# Drawdowns (the percent decline from a previous peak) are easy to plot ...

# %%
rf3.drawdowns.plot();

# %%
rf3.drawdowns.nsmallest(5)  # 5 Biggest drawdowns
# Out:
# date
# 2022-09   -0.261806
# 2022-06   -0.224394
# 2022-12   -0.219780
# 2022-10   -0.209189
# 2022-08   -0.183931
# Freq: M, Name: RF3_portfolio.PF, dtype: float64

# %% [markdown]
# `reovery_period` highly related with Drawdowns. It shows the longest recovery periods for the portfolio value after drawdowns.

# %%
rf3.recovery_period.nlargest() / 12  # we want it in years
# Out:
# date
# 2023-12    1.916667
# 2019-04    0.500000
# 2016-05    0.416667
# 2018-07    0.416667
# 2020-06    0.333333
# Freq: M, Name: RF3_portfolio.PF, dtype: float64

# %% [markdown]
# ### Accumulated return, CAGR and dividend yield

# %% [markdown]
# Portfolio has several metrics to measure the profits and return:

# %% [markdown]
# - wealth_index (the value of portfolio over historical time period)
# - wealth_index_with_assets (wealth index with assets values)
# - mean_return_monthly (arithmetic mean for the portfolio rate of return)
# - mean_return_annual (annualized value for monthly mean)
# - annual_return_ts (Annual rate of return time series)
# - get_cagr (Compound Annual Growth Rate for a given trailing period)
# - get_rolling_cagr (rolling CAGR with)
# - get_cumulative_return (cumulative return over a given trailing period)
# - get_rolling_cumulative_return (rolling cumulative return)
# - dividend_yield (portfolio LTM dividend yield monthly time series)

# %% [markdown]
# Wealth index is a simpliest time series showing portfolio value growth (we have already seen it here). Sometimes it's worth to compare portfolio value growth with assets values.
# For that mean there is `wealth_index_with_assets` method.

# %%
rf3.wealth_index_with_assets.plot();

# %% [markdown]
# Mean reaturn (arithmetic mean) for the portfolio is an annualized version of monthly mean:

# %%
rf3.mean_return_annual
# Out:
# 0.16492449511626517

# %% [markdown]
# It's always good to see how portfolio perform on annual basis. Annual rate of return time series show portfolio return for each calendar year:

# %%
rf3.annual_return_ts
# Out:
# date
# 2015   -0.012715
# 2016    0.110796
# 2017    0.238511
# 2018   -0.036226
# 2019    0.329415
# 2020    0.251170
# 2021    0.284233
# 2022   -0.219780
# 2023    0.327853
# 2024    0.213396
# Freq: Y-DEC, Name: RF3_portfolio.PF, dtype: float64

# %% [markdown]
# ... or in form of bar chart:

# %%
rf3.annual_return_ts.plot(kind="bar");

# %% [markdown]
# One of the most important return metrics is CAGR (Compound Annual Growth Rate). It can be seen for trailing periods (parameter *period* is in years):

# %%
rf3.get_cagr(period=5)  # portfolio is initiated with inflation=True. Hence, we see CAGR with mean inflation.
# Out:
# RF3_portfolio.PF    0.172809
# USD.INFL            0.041976
# dtype: float64

# %%
rf3.get_cagr(period=5, real=True)  # when real=True CAGR is adjusted for inflation (real CAGR)
# Out:
# RF3_portfolio.PF    0.125563
# dtype: float64

# %% [markdown]
# Rolling CAGR for the portfolio is available with `get_rolling_cagr`:

# %%
rf3.get_rolling_cagr(
    window=12 * 2
).plot();  # window size is in moths. We have rolling 2 year CAGR here and rolling 2 year mean inflation ...

# %% [markdown]
# Cumulative return over a given trailing period can be calculated with `get_cumulative_return`. Period argument can be in years or YTD (Year To Date).

# %%
rf3.get_cumulative_return(
    period="YTD"
)  # Return since the beginning of the current calendar year and the inflation for the same period
# Out:
# RF3_portfolio.PF    0.213396
# USD.INFL            0.027916
# dtype: float64

# %%
rf3.get_cumulative_return(period=5)  # Cumulative return for the 5 years period
# Out:
# RF3_portfolio.PF    1.218894
# USD.INFL            0.228253
# dtype: float64

# %% [markdown]
# Cumulative rolling return can be helpfull in the same situation as rolling CAGR:

# %%
rf3.get_rolling_cumulative_return(window=12 * 5).plot();  # window size is in months (5 year cumulative return here)

# %% [markdown]
# Last twelve months (LTM) dividend yield is available with `dividend_yield` property.

# %%
rf3.dividend_yield.plot();

# %% [markdown]
# Portfolio has monthly dividends time series:

# %%
rf3.dividends
# Out:
# date
# 2015-11    0.000000
# 2015-12    5.347449
# 2016-01    0.000000
# 2016-02    0.000000
# 2016-03    4.438988
#              ...
# 2024-05    0.000000
# 2024-06    9.361996
# 2024-07    0.000000
# 2024-08    0.000000
# 2024-09    9.043118
# Freq: M, Name: RF3_portfolio.PF, Length: 107, dtype: float64

# %% [markdown]
# Calendar year dividends sum time series for the portfolio:

# %%
rf3.dividends.resample("Y").sum().plot(kind="bar");

# %% [markdown]
#  **Sharpe Ratio** was developed by Nobel laureate William F. Sharpe and is used to understand the return of an investment compared to its risk.

# %% [markdown]
# $$
# S_p = \frac{R_p - R_f}{\sigma_p}
# $$
# $R_p$ - expected return of portfolio
# $R_f$ - risk-free rate of return
# $\sigma_p$ - portfolio risk (standard deviation of return)

# %%
rf3.get_sharpe_ratio(rf_return=0.02)  # risk-free rate is 2% here
# Out:
# 0.7827496539019857

# %% [markdown]
# Finally the easiest way to see the portfolio basic properties is with `describe`:

# %%
rf3.describe()
# Out:
#                   property              period RF3_portfolio.PF  inflation
# 0          compound return                 YTD         0.213396   0.027916
# 1                     CAGR             1 years         0.364239   0.024425
# 2                     CAGR             5 years         0.172809   0.041976
# 3                     CAGR            10 years              NaN        NaN
# 4                     CAGR  8 years, 11 months         0.151403   0.032142
# 5   Annualized mean return  8 years, 11 months         0.164924        NaN
# 6           Dividend yield                 LTM         0.010863        NaN
# 7                     Risk  8 years, 11 months         0.185148        NaN
# 8                     CVAR  8 years, 11 months          0.21978        NaN
# 9             Max drawdown  8 years, 11 months        -0.261806        NaN
# 10       Max drawdown date  8 years, 11 months          2022-09        NaN

# %% [markdown]
# ### Compare several portfolios

# %% [markdown]
# Portfolio is a kind of financial asset and can be included in AssetList to compare with other portfolios (assets or benchmarks).

# %% [markdown]
# Lets create  Rick Ferri 4 assets portfolio and compare the behaviour with 3 assets portfolio.

# %%
assets = ["BND.US", "VTI.US", "VXUS.US", "VNQ.US"]  # Vanguard REIT ETF (VNQ) is added.
weights = [0.40, 0.30, 0.24, 0.06]

# %% [markdown]
# To compare properly with RF3 portfolio the same rebalancing period should be chosen:

# %%
rf4 = ok.Portfolio(
    assets=assets, weights=weights, rebalancing_period="year", symbol="RF4_portfolio.PF"
)  # we also give a custom name to portfolio with 'symbol' propety
rf4
# Out:
# symbol                                 RF4_portfolio.PF
# assets                [BND.US, VTI.US, VXUS.US, VNQ.US]
# weights                          [0.4, 0.3, 0.24, 0.06]
# rebalancing_period                                 year
# currency                                            USD
# inflation                                      USD.INFL
# first_date                                      2011-02
# last_date                                       2024-09
# period_length                        13 years, 8 months
# dtype: object

# %% [markdown]
# Now we create an AssetList to compare RF3 with RF4 and add a benchamrk (SP 500 TR index).

# %%
ls = ok.AssetList(["SP500TR.INDX", rf3, rf4])
ls
# Out:
# assets           [SP500TR.INDX, RF3_portfolio.PF, RF4_portfolio...
# currency                                                       USD
# first_date                                                 2015-11
# last_date                                                  2024-09
# period_length                                   8 years, 11 months
# inflation                                                 USD.INFL
# dtype: object

# %% [markdown]
# Some behavior will be seen with `wealth_indexes`:

# %%
ls.wealth_indexes.plot();

# %% [markdown]
# It worth plotting the portfolios and benchmark on the risk / return chart with `plot_assets`.<br>
# **X-axis** is Risk (Standard Deviation)
# **Y-axis** is Return (Mean return or CAGR)

# %%
ls.plot_assets(kind="cagr");  # we chouse CAGR (geomtric mean of return) as Y-axis by setting kind='cagr'

# %% [markdown]
# **See [04 efficient frontier single period.ipynb](https://github.com/mbk-dev/okama/blob/master/examples/04%20efficient%20frontier%20single%20period.ipynb) and [05 efficient frontier multi-period.ipynb](https://github.com/mbk-dev/okama/blob/master/examples/05%20efficient%20frontier%20multi-period.ipynb) to plot portfolios with the Efficient Frontier.**

# %% [markdown]
# Given risk-free rate it's easy to compare **Sharpe Ratios** of the portfolios and match it with the benchmark with `get_sharpe_ratio`:

# %%
ls.get_sharpe_ratio(rf_return=0.02)  # Risk-Free rate is 2% here
# Out:
# Symbols
# SP500TR.INDX        0.760139
# RF3_portfolio.PF    0.788292
# RF4_portfolio.PF    0.501654
# dtype: float64

# %% [markdown]
# Most important information can be seen for trailing periods with `describe` method.
# It shows "descriptive statistics":
#
# - YTD (Year To date) compound return
# - CAGR for a given list of periods and full available period
# - Annualized mean rate of return (arithmetic mean)
# - LTM Dividend yield - last twelve months dividend yield
#
# Risk metrics (full period):
#
# - risk (standard deviation)
# - CVAR (timeframe is 1 year)
# - max drawdowns (and dates of the drawdowns)

# %%
ls.describe([1, 5, 8])  # portfolio CAGR is shown for YTD, 1, 5, 8 years and for the full histrical period.
# Out:
#                   property              period SP500TR.INDX RF3_portfolio.PF  \
# 0          Compound return                 YTD     0.221048         0.213396
# 1                     CAGR             1 years     0.363773         0.364239
# 2                     CAGR             5 years     0.159875         0.172809
# 3                     CAGR             8 years     0.150125          0.16129
# 4                     CAGR  8 years, 11 months       0.1417         0.151403
# 5   Annualized mean return  8 years, 11 months     0.155289         0.165951
# 6           Dividend yield                 LTM          0.0         0.010674
# 7                     Risk  8 years, 11 months      0.17798         0.185148
# 8                     CVAR  8 years, 11 months      0.18101          0.21978
# 9            Max drawdowns  8 years, 11 months    -0.238631        -0.261806
# 10     Max drawdowns dates  8 years, 11 months      2022-09          2022-09
# 11          Inception date                None      1988-02          2015-11
# 12         Last asset date                None      2024-10          2024-09
# 13   Common last data date                None      2024-09          2024-09
#
#    RF4_portfolio.PF inflation
# 0          0.120632  0.027916
# 1           0.23087  0.024425
# 2          0.069856  0.041976
# 3          0.070192  0.033956
# 4          0.069323  0.032142
# 5           0.07485       NaN
# 6          0.025391       NaN
# 7          0.109339       NaN
# 8           0.18416       NaN
# 9         -0.213989       NaN
# 10          2022-09       NaN
# 11          2011-02   2015-11
# 12          2024-09   2024-09
# 13          2024-09   2024-09

# %% [markdown]
# ### Forecast portfolios performance

# %% [markdown]
# Forecasting methods are described in a dedicated notebook [07 forecasting.ipynb](https://github.com/mbk-dev/okama/blob/master/examples/07%20forecasting.ipynb).
